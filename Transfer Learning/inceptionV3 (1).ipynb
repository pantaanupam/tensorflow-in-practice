# %% [markdown]
# # Loading images and image preprocessing

# %%
# !wget --no-check-certificate \
        https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip \
       -O /tmp/cats_and_dogs_filtered.zip
# Out:
# --2020-07-17 13:06:31--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.197.128, 74.125.135.128, 74.125.142.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.197.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘/tmp/cats_and_dogs_filtered.zip’
#
# /tmp/cats_and_dogs_ 100%[===================>]  65.43M   110MB/s    in 0.6s
#
# 2020-07-17 13:06:31 (110 MB/s) - ‘/tmp/cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
import os
import zipfile

local_zip = '/tmp/cats_and_dogs_filtered.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
train_dir = '/tmp/cats_and_dogs_filtered/train'
validation_dir = '/tmp/cats_and_dogs_filtered/validation'

train_cats_dir = os.path.join(train_dir, 'cats') 
train_dogs_dir = os.path.join(train_dir, 'dogs') 
validation_cats_dir = os.path.join(validation_dir, 'cats') 
validation_dogs_dir = os.path.join(validation_dir, 'dogs')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Adding our data-augmentation parameters to ImageDataGenerator
train_datagen = ImageDataGenerator(rescale=1.0/255.,
                                   rotation_range = 0.2,
                                   width_shift_range = 0.2,
                                   height_shift_range = 0.2,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1.0/255.)

# Flow training images in batches of 20
train_generator = train_datagen.flow_from_directory(train_dir, 
                                                    batch_size = 20,
                                                    class_mode = 'binary',
                                                    target_size = (150, 150))
validation_generator = test_datagen.flow_from_directory(validation_dir,
                                                        batch_size = 20,
                                                        class_mode = 'binary',
                                                        target_size = (150, 150))
# Out:
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# # Loading Inception Model

# %%
# inception model weights

# !wget --no-check-certificate \
    https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5 \
    -O /tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# Out:
# --2020-07-17 13:06:36--  https://storage.googleapis.com/mledu-datasets/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 74.125.195.128, 2607:f8b0:400e:c08::80, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 87910968 (84M) [application/x-hdf]
# Saving to: ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’
#
# /tmp/inception_v3_w 100%[===================>]  83.84M  91.5MB/s    in 0.9s
#
# 2020-07-17 13:06:37 (91.5 MB/s) - ‘/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5’ saved [87910968/87910968]

# %%
import os
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3

load_weights_file = '/tmp/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5'

pre_trained_model = InceptionV3(input_shape = (150, 150, 3),
                                include_top = False,
                                weights = None)

pre_trained_model.load_weights(load_weights_file)

# %%
# last layer
last_layer = pre_trained_model.get_layer('mixed7')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 7, 7, 768)

# %% [markdown]
# # Building Model on top of pre_trained_model

# %%
x = tf.keras.layers.Flatten()(last_output)

x = tf.keras.layers.Dense(1024, activation='relu')(x)

# x = tf.keras.layers.Dropout(0.2)(x)

x = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(pre_trained_model.input, x)

# %%
# model.summary()

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(optimizer = RMSprop(lr=0.0001), 
              loss = 'binary_crossentropy', 
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                    validation_data = validation_generator,
                    epochs = 20,
                    verbose = 1)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 22s 216ms/step - loss: 0.3440 - accuracy: 0.8510 - val_loss: 0.1890 - val_accuracy: 0.9500
# Epoch 2/20
# 100/100 [==============================] - 21s 207ms/step - loss: 0.1887 - accuracy: 0.9250 - val_loss: 0.6848 - val_accuracy: 0.9150
# Epoch 3/20
# 100/100 [==============================] - 20s 205ms/step - loss: 0.1449 - accuracy: 0.9530 - val_loss: 0.3918 - val_accuracy: 0.9470
# Epoch 4/20
# 100/100 [==============================] - 21s 205ms/step - loss: 0.1240 - accuracy: 0.9630 - val_loss: 0.8854 - val_accuracy: 0.9370
# Epoch 5/20
# 100/100 [==============================] - 21s 206ms/step - loss: 0.0706 - accuracy: 0.9765 - val_loss: 0.5314 - val_accuracy: 0.9560
# Epoch 6/20
# 100/100 [==============================] - 20s 205ms/step - loss: 0.0876 - accuracy: 0.9725 - val_loss: 0.4460 - val_accuracy: 0.9520
# Epoch 7/20
# 100/100 [==============================] - 20s 203ms/step - loss: 0.0733 - accuracy: 0.9785 - val_loss: 0.8121 - val_accuracy: 0.9400
# Epoch 8/20
# 100/100 [==============================] - 20s 205ms/step - loss: 0.0791 - accuracy: 0.9800 - val_loss: 1.0544 - val_accuracy: 0.9440
# Epoch 9/20
# 100/100 [==============================] - 21s 205ms/step - loss: 0.0877 - accuracy: 0.9780 - val_loss: 1.6350 - val_accuracy: 0.9370
# Epoch 10/20
# 100/100 [==============================] - 20s 205ms/step - loss: 0.0490 - accuracy: 0.9890 - val_loss: 0.7070 - val_accuracy: 0.9510
# Epoch 11/20
# 100/100 [==============================] - 20s 205ms/step - loss: 0.0819 - accuracy: 0.9780 - val_loss: 0.4410 - val_accuracy: 0.9670
# Epoch 12/20
# 100/100 [==============================] - 21s 206ms/step - loss: 0.0496 - accuracy: 0.9860 - val_loss: 1.2700 - val_accuracy: 0.9340
# Epoch 13/20
# 100/100 [==============================] - 21s 206ms/step - loss: 0.0271 - accuracy: 0.9910 - val_loss: 0.3325 - val_accuracy: 0.9570
# Epoch 14/20
# 100/100 [==============================] - 21s 206ms/step - loss: 0.0865 - accuracy: 0.9825 - val_loss: 0.8191 - val_accuracy: 0.9420
# Epoch 15/20
# 100/100 [==============================] - 21s 208ms/step - loss: 0.0677 - accuracy: 0.9850 - val_loss: 0.7100 - val_accuracy: 0.9350
# Epoch 16/20
# 100/100 [==============================] - 21s 206ms/step - loss: 0.0409 - accuracy: 0.9900 - val_loss: 0.3538 - val_accuracy: 0.9500
# Epoch 17/20
# 100/100 [==============================] - 21s 207ms/step - loss: 0.0381 - accuracy: 0.9900 - val_loss: 1.1796 - val_accuracy: 0.9380
# Epoch 18/20
# 100/100 [==============================] - 21s 205ms/step - loss: 0.0548 - accuracy: 0.9915 - val_loss: 10.7429 - val_accuracy: 0.8020
# Epoch 19/20
# 100/100 [==============================] - 21s 206ms/step - loss: 0.0337 - accuracy: 0.9900 - val_loss: 0.4427 - val_accuracy: 0.9440
# Epoch 20/20
# 100/100 [==============================] - 21s 207ms/step - loss: 0.0376 - accuracy: 0.9900 - val_loss: 0.4219 - val_accuracy: 0.9580

# %% [markdown]
# # Visualizing model accuracy

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()


plt.show()
